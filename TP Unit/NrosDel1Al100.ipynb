# %%
def esFizz(unNumero) :
    return (unNumero % 3) == 0

# %%
def esBuzz(unNumero) :
    return (unNumero % 5) == 0

# %%
def esFizzBuzz(unNumero) :
    return esFizz(unNumero) and esBuzz(unNumero)

# %%
def nrosDel1Al100ConFizzBuzz():
    salida = []
    for contador in range(1, 101) :
        valor = contador
        if(esFizzBuzz(contador)):
            valor = "FizzBuzz"
        elif(esFizz(contador)):
            valor = "Fizz"
        elif(esBuzz(contador)):
            valor = "Buzz"
        salida.append(valor)
    return salida

print(nrosDel1Al100ConFizzBuzz())
# Out:
# [1, 2, 'Fizz', 4, 'Buzz', 'Fizz', 7, 8, 'Fizz', 'Buzz', 11, 'Fizz', 13, 14, 'FizzBuzz', 16, 17, 'Fizz', 19, 'Buzz', 'Fizz', 22, 23, 'Fizz', 'Buzz', 26, 'Fizz', 28, 29, 'FizzBuzz', 31, 32, 'Fizz', 34, 'Buzz', 'Fizz', 37, 38, 'Fizz', 'Buzz', 41, 'Fizz', 43, 44, 'FizzBuzz', 46, 47, 'Fizz', 49, 'Buzz', 'Fizz', 52, 53, 'Fizz', 'Buzz', 56, 'Fizz', 58, 59, 'FizzBuzz', 61, 62, 'Fizz', 64, 'Buzz', 'Fizz', 67, 68, 'Fizz', 'Buzz', 71, 'Fizz', 73, 74, 'FizzBuzz', 76, 77, 'Fizz', 79, 'Buzz', 'Fizz', 82, 83, 'Fizz', 'Buzz', 86, 'Fizz', 88, 89, 'FizzBuzz', 91, 92, 'Fizz', 94, 'Buzz', 'Fizz', 97, 98, 'Fizz', 'Buzz']

# %%
import unittest

class unoAlCienTest(unittest.TestCase):
    def testDadaUnaListaDel1Al100ConFizzBuzzCuandoLlamoAUnNumeroDivisiblePor3EntoncesMeDevelveFizz(self):
        actual = nrosDel1Al100ConFizzBuzz()[2]
        esperado = "Fizz"
        self.assertEqual(esperado , actual)

    def testDadaUnaListaDel1Al100ConFizzBuzzCuandoLlamoAUnNumeroDivisiblePor5EntoncesMeDevelveBuzz(self):
        actual = nrosDel1Al100ConFizzBuzz()[4]
        esperado = "Buzz"
        self.assertEqual(esperado , actual)

    def testDadaUnaListaDel1Al100ConFizzBuzzCuandoLlamoAUnNumeroDivisiblePor3Y5EntoncesMeDevelveFizzBuzz(self):
        actual = nrosDel1Al100ConFizzBuzz()[14]
        esperado = "FizzBuzz"
        self.assertEqual(esperado , actual)

    def testDadaUnaListaDel1Al100ConFizzBuzzCuandoLlamoAUnNumeroNoDivisiblePor3Y5EntoncesMeDevelveEseMismoNumero(self):
        actual = nrosDel1Al100ConFizzBuzz()[3]
        esperado = 4
        self.assertEqual(esperado , actual)

unittest.main(defaultTest="unoAlCienTest" , argv=[""] , verbosity=2 , exit=False)
# Out:
# testDadaUnaListaDel1Al100ConFizzBuzzCuandoLlamoAUnNumeroDivisiblePor3EntoncesMeDevelveFizz (__main__.unoAlCienTest.testDadaUnaListaDel1Al100ConFizzBuzzCuandoLlamoAUnNumeroDivisiblePor3EntoncesMeDevelveFizz) ... ok
# testDadaUnaListaDel1Al100ConFizzBuzzCuandoLlamoAUnNumeroDivisiblePor3Y5EntoncesMeDevelveFizzBuzz (__main__.unoAlCienTest.testDadaUnaListaDel1Al100ConFizzBuzzCuandoLlamoAUnNumeroDivisiblePor3Y5EntoncesMeDevelveFizzBuzz) ... ok
# testDadaUnaListaDel1Al100ConFizzBuzzCuandoLlamoAUnNumeroDivisiblePor5EntoncesMeDevelveBuzz (__main__.unoAlCienTest.testDadaUnaListaDel1Al100ConFizzBuzzCuandoLlamoAUnNumeroDivisiblePor5EntoncesMeDevelveBuzz) ... ok
# testDadaUnaListaDel1Al100ConFizzBuzzCuandoLlamoAUnNumeroNoDivisiblePor3Y5EntoncesMeDevelveEseMismoNumero (__main__.unoAlCienTest.testDadaUnaListaDel1Al100ConFizzBuzzCuandoLlamoAUnNumeroNoDivisiblePor3Y5EntoncesMeDevelveEseMismoNumero) ... ok
#
# ----------------------------------------------------------------------
# ...
