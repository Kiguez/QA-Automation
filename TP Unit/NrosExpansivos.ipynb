# %%
def expand(expansivo):
    salida = []
    contador = 1
    for e in range (len(expansivo) - 1):
        actual = expansivo[e]
        siguiente = expansivo[e + 1]
        if(actual == siguiente):
            contador = contador + 1
        else:
            salida.append(contador)
            salida.append(actual)
            contador = 1
    salida.append(contador)
    salida.append(expansivo[- 1])

    return salida

# %%
import unittest

class expandTest(unittest.TestCase):
    def testDadoUnNumeroExpansivo1CuandoCalculoSuSiguienteEntoncesObtengo11(self):
        actual = expand([1])
        esperado = [1 , 1]
        self.assertEqual(esperado , actual)

    def testDadoUnNumeroExpansivo11CuandoCalculoSuSiguienteEntoncesObtengo21(self):
        actual = expand([1 , 1])
        esperado = [2 , 1]
        self.assertEqual(esperado , actual)

    def testDadoUnNumeroExpansivo21CuandoCalculoSuSiguienteEntoncesObtengo1211(self):
        actual = expand([2 , 1])
        esperado = [1 , 2 , 1 , 1]
        self.assertEqual(esperado , actual)

    def testDadoUnNumeroExpansivo1211CuandoCalculoSuSiguienteEntoncesObtengo111221(self):
        actual = expand([1 , 2 , 1 , 1])
        esperado = [1 , 1 , 1 , 2 , 2 , 1]
        self.assertEqual(esperado , actual)


unittest.main(defaultTest="expandTest" , argv=[""] , verbosity=2 , exit=False)
# Out:
# testDadoUnNumeroExpansivo11CuandoCalculoSuSiguienteEntoncesObtengo21 (__main__.expandTest.testDadoUnNumeroExpansivo11CuandoCalculoSuSiguienteEntoncesObtengo21) ... ok
# testDadoUnNumeroExpansivo1211CuandoCalculoSuSiguienteEntoncesObtengo111221 (__main__.expandTest.testDadoUnNumeroExpansivo1211CuandoCalculoSuSiguienteEntoncesObtengo111221) ... ok
# testDadoUnNumeroExpansivo1CuandoCalculoSuSiguienteEntoncesObtengo11 (__main__.expandTest.testDadoUnNumeroExpansivo1CuandoCalculoSuSiguienteEntoncesObtengo11) ... ok
# testDadoUnNumeroExpansivo21CuandoCalculoSuSiguienteEntoncesObtengo1211 (__main__.expandTest.testDadoUnNumeroExpansivo21CuandoCalculoSuSiguienteEntoncesObtengo1211) ... ok
#
# ----------------------------------------------------------------------
# Ran 4 tests in 0.006s
#
# OK

# %%
def list2num(expansivo):
    salida = []
    for e in range(0 , (len(expansivo) - 1) , 2):
        actual = expansivo[e]
        siguiente = expansivo[e + 1]
        for n in range (actual):
            salida.append(siguiente)
    return salida
# Out:
# [1, 2, 1, 1]

# %%
class list2numTest(unittest.TestCase):
    def testDadoUnNumeroExpansivo11CuandoCalculoSuSiguienteEntoncesObtengo1(self):
        actual = list2num([1 , 1])
        esperado = [1]
        self.assertEqual(esperado , actual)

    def testDadoUnNumeroExpansivo21CuandoCalculoSuSiguienteEntoncesObtengo11(self):
        actual = list2num([2 , 1])
        esperado = [1 , 1]
        self.assertEqual(esperado , actual)

    def testDadoUnNumeroExpansivo1211CuandoCalculoSuSiguienteEntoncesObtengo21(self):
        actual = list2num([1 , 2 , 1 , 1])
        esperado = [2 , 1]
        self.assertEqual(esperado , actual)

    def testDadoUnNumeroExpansivo111221CuandoCalculoSuSiguienteEntoncesObtengo1211(self):
        actual = list2num([1 , 1 , 1 , 2 , 2 , 1])
        esperado = [1 , 2 , 1 , 1]
        self.assertEqual(esperado , actual)


unittest.main(defaultTest="list2numTest" , argv=[""] , verbosity=2 , exit=False)
# Out:
# testDadoUnNumeroExpansivo111221CuandoCalculoSuSiguienteEntoncesObtengo1211 (__main__.list2numTest.testDadoUnNumeroExpansivo111221CuandoCalculoSuSiguienteEntoncesObtengo1211) ... ok
# testDadoUnNumeroExpansivo11CuandoCalculoSuSiguienteEntoncesObtengo1 (__main__.list2numTest.testDadoUnNumeroExpansivo11CuandoCalculoSuSiguienteEntoncesObtengo1) ... ok
# testDadoUnNumeroExpansivo1211CuandoCalculoSuSiguienteEntoncesObtengo21 (__main__.list2numTest.testDadoUnNumeroExpansivo1211CuandoCalculoSuSiguienteEntoncesObtengo21) ... ok
# testDadoUnNumeroExpansivo21CuandoCalculoSuSiguienteEntoncesObtengo11 (__main__.list2numTest.testDadoUnNumeroExpansivo21CuandoCalculoSuSiguienteEntoncesObtengo11) ... ok
#
# ----------------------------------------------------------------------
# Ran 4 tests in 0.017s
#
# OK
